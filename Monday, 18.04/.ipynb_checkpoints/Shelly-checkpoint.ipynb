# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 50

# %% [markdown]
# ## Exploring the Data
# ### 1. Loading
# ### 2. Renaming
# ### 3. Checking for missing values and zeros
# ### 4. Dropping duplicates
# ### 5. Checking outliers

# %%
file1 = pd.read_csv('abalone.csv')

# %%
def load_original_data():
    return pd.concat([file1])

# %%
aba=load_original_data()

# %%
aba
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
def lower_case_column_names(aba):
    aba.columns=[i.lower() for i in aba.columns]
    return aba

# %%
lower_case_column_names(aba)
# Out:
#      sex  length  diameter  height  whole weight  shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       viscera weight  shell weight  rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
aba.isna().sum()
# Out:
# sex               0
# length            0
# diameter          0
# height            0
# whole weight      0
# shucked weight    0
# viscera weight    0
# shell weight      0
# rings             0
# dtype: int64

# %% [markdown]
# ## no NAN values

# %%
aba.describe()
# Out:
#             length     diameter       height  whole weight  shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        viscera weight  shell weight        rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
aba['height'].value_counts(0.00)
# Out:
# 0.150    267
# 0.140    220
# 0.155    217
# 0.175    211
# 0.160    205
#         ...
# 0.015      2
# 0.000      2
# 0.010      1
# 0.515      1
# 1.130      1
# Name: height, Length: 51, dtype: int64

# %% [markdown]
# ## Two 0.000 values for height

# %%
aba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             4177 non-null   object
#  1   length          4177 non-null   float64
#  2   diameter        4177 non-null   float64
#  3   height          4177 non-null   float64
#  4   whole weight    4177 non-null   float64
#  5   shucked weight  4177 non-null   float64
#  6   viscera weight  4177 non-null   float64
#  7   shell weight    4177 non-null   float64
#  8   rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
aba.rename(columns={'shucked weight':'shucked_weight_meat'}, inplace=True)

# %%
aba.rename(columns={'viscera weight':'gut_weight'},inplace=True)

# %%
aba.rename(columns={'whole weight':'whole_weight'},inplace=True)

# %%
aba.rename(columns={'shell weight':'shell_weight'},inplace=True)

# %%
aba
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight_meat  \
# 0      M   0.455     0.365   0.095        0.5140               0.2245
# 1      M   0.350     0.265   0.090        0.2255               0.0995
# 2      F   0.530     0.420   0.135        0.6770               0.2565
# 3      M   0.440     0.365   0.125        0.5160               0.2155
# 4      I   0.330     0.255   0.080        0.2050               0.0895
# ...   ..     ...       ...     ...           ...                  ...
# 4172   F   0.565     0.450   0.165        0.8870               0.3700
# 4173   M   0.590     0.440   0.135        0.9660               0.4390
# 4174   M   0.600     0.475   0.205        1.1760               0.5255
# 4175   F   0.625     0.485   0.150        1.0945               0.5310
# 4176   M   0.710     0.555   0.195        1.9485               0.9455
#
#       gut_weight  shell_weight  rings
# 0         0.1010        0.1500     15
# 1         0.0485        0.0700      7
# 2         0.1415        0.2100      9
# 3         0.1140        0.1550     10
# 4         0.0395        0.0550      7
# ...          ...           ...    ...
# 4172      0.2390        0.2490     11
# 4173      0.2145        0.2605     10
# 4174      0.2875        0.3080      9
# 4175      0.2610        0.2960     10
# 4176      0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
Q1=aba.quantile(0.10)
Q3=aba.quantile(0.90)
IQR=Q3 - Q1
print(IQR)
# Out:
# length                 0.3050
# diameter               0.2570
# height                 0.0950
# whole_weight           1.2732
# shucked_weight_meat    0.5605
# gut_weight             0.2827
# shell_weight           0.3550
# rings                  8.0000
# age                    8.0000
# dtype: float64

# %%
aba_ed=aba[~((aba < (Q1-1.5*IQR)) | (aba > (Q3 + 1.5 * IQR))).any(axis=1)]
print(aba_ed.shape)
# Out:
# (4169, 10)
# /var/folders/r9/4d41b7251kd4g8mywhld0w_80000gn/T/ipykernel_4375/744516010.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   aba_ed=aba[~((aba < (Q1-1.5*IQR)) | (aba > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# # Transforming the Data
#
# ## 1. Create new variable age
# ## 2. Transform sex to dummies

# %%
aba['age']=aba['rings']+1.5

# %%
aba.drop(['rings'], axis=1)
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight_meat  \
# 0      M   0.455     0.365   0.095        0.5140               0.2245
# 1      M   0.350     0.265   0.090        0.2255               0.0995
# 2      F   0.530     0.420   0.135        0.6770               0.2565
# 3      M   0.440     0.365   0.125        0.5160               0.2155
# 4      I   0.330     0.255   0.080        0.2050               0.0895
# ...   ..     ...       ...     ...           ...                  ...
# 4172   F   0.565     0.450   0.165        0.8870               0.3700
# 4173   M   0.590     0.440   0.135        0.9660               0.4390
# 4174   M   0.600     0.475   0.205        1.1760               0.5255
# 4175   F   0.625     0.485   0.150        1.0945               0.5310
# 4176   M   0.710     0.555   0.195        1.9485               0.9455
#
#       gut_weight  shell_weight   age  F  I  M
# 0         0.1010        0.1500  16.5  0  0  1
# 1         0.0485        0.0700   8.5  0  0  1
# 2         0.1415        0.2100  10.5  1  0  0
# 3         0.1140        0.1550  11.5  0  0  1
# 4         0.0395        0.0550   8.5  0  1  0
# ...          ...           ...   ... .. .. ..
# 4172      0.2390        0.2490  12.5  1  0  0
# 4173      0.2145        0.2605  11.5  0  0  1
# 4174      0.2875        0.3080  10.5  0  0  1
# 4175      0.2610        0.2960  11.5  1  0  0
# 4176      0.3765        0.4950  13.5  0  0  1
#
# [4169 rows x 12 columns]

# %%
aba.drop_duplicates()
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight_meat  \
# 0      M   0.455     0.365   0.095        0.5140               0.2245
# 1      M   0.350     0.265   0.090        0.2255               0.0995
# 2      F   0.530     0.420   0.135        0.6770               0.2565
# 3      M   0.440     0.365   0.125        0.5160               0.2155
# 4      I   0.330     0.255   0.080        0.2050               0.0895
# ...   ..     ...       ...     ...           ...                  ...
# 4172   F   0.565     0.450   0.165        0.8870               0.3700
# 4173   M   0.590     0.440   0.135        0.9660               0.4390
# 4174   M   0.600     0.475   0.205        1.1760               0.5255
# 4175   F   0.625     0.485   0.150        1.0945               0.5310
# 4176   M   0.710     0.555   0.195        1.9485               0.9455
#
#       gut_weight  shell_weight  rings   age  F  I  M
# 0         0.1010        0.1500     15  16.5  0  0  1
# 1         0.0485        0.0700      7   8.5  0  0  1
# 2         0.1415        0.2100      9  10.5  1  0  0
# 3         0.1140        0.1550     10  11.5  0  0  1
# 4         0.0395        0.0550      7   8.5  0  1  0
# ...          ...           ...    ...   ... .. .. ..
# 4172      0.2390        0.2490     11  12.5  1  0  0
# 4173      0.2145        0.2605     10  11.5  0  0  1
# 4174      0.2875        0.3080      9  10.5  0  0  1
# 4175      0.2610        0.2960     10  11.5  1  0  0
# 4176      0.3765        0.4950     12  13.5  0  0  1
#
# [4169 rows x 13 columns]

# %%
aba
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight_meat  \
# 0      M   0.455     0.365   0.095        0.5140               0.2245
# 1      M   0.350     0.265   0.090        0.2255               0.0995
# 2      F   0.530     0.420   0.135        0.6770               0.2565
# 3      M   0.440     0.365   0.125        0.5160               0.2155
# 4      I   0.330     0.255   0.080        0.2050               0.0895
# ...   ..     ...       ...     ...           ...                  ...
# 4172   F   0.565     0.450   0.165        0.8870               0.3700
# 4173   M   0.590     0.440   0.135        0.9660               0.4390
# 4174   M   0.600     0.475   0.205        1.1760               0.5255
# 4175   F   0.625     0.485   0.150        1.0945               0.5310
# 4176   M   0.710     0.555   0.195        1.9485               0.9455
#
#       gut_weight  shell_weight  rings   age  F  I  M
# 0         0.1010        0.1500     15  16.5  0  0  1
# 1         0.0485        0.0700      7   8.5  0  0  1
# 2         0.1415        0.2100      9  10.5  1  0  0
# 3         0.1140        0.1550     10  11.5  0  0  1
# 4         0.0395        0.0550      7   8.5  0  1  0
# ...          ...           ...    ...   ... .. .. ..
# 4172      0.2390        0.2490     11  12.5  1  0  0
# 4173      0.2145        0.2605     10  11.5  0  0  1
# 4174      0.2875        0.3080      9  10.5  0  0  1
# 4175      0.2610        0.2960     10  11.5  1  0  0
# 4176      0.3765        0.4950     12  13.5  0  0  1
#
# [4169 rows x 13 columns]

# %%
sex_num = pd.get_dummies(aba_ed['sex'])  
aba = pd.concat([aba_ed,sex_num],axis=1)

# %%
aba = pd.concat([aba_ed,sex_num],axis=1)

# %%
aba
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight_meat  \
# 0      M   0.455     0.365   0.095        0.5140               0.2245
# 1      M   0.350     0.265   0.090        0.2255               0.0995
# 2      F   0.530     0.420   0.135        0.6770               0.2565
# 3      M   0.440     0.365   0.125        0.5160               0.2155
# 4      I   0.330     0.255   0.080        0.2050               0.0895
# ...   ..     ...       ...     ...           ...                  ...
# 4172   F   0.565     0.450   0.165        0.8870               0.3700
# 4173   M   0.590     0.440   0.135        0.9660               0.4390
# 4174   M   0.600     0.475   0.205        1.1760               0.5255
# 4175   F   0.625     0.485   0.150        1.0945               0.5310
# 4176   M   0.710     0.555   0.195        1.9485               0.9455
#
#       gut_weight  shell_weight  rings   age  F  I  M
# 0         0.1010        0.1500     15  16.5  0  0  1
# 1         0.0485        0.0700      7   8.5  0  0  1
# 2         0.1415        0.2100      9  10.5  1  0  0
# 3         0.1140        0.1550     10  11.5  0  0  1
# 4         0.0395        0.0550      7   8.5  0  1  0
# ...          ...           ...    ...   ... .. .. ..
# 4172      0.2390        0.2490     11  12.5  1  0  0
# 4173      0.2145        0.2605     10  11.5  0  0  1
# 4174      0.2875        0.3080      9  10.5  0  0  1
# 4175      0.2610        0.2960     10  11.5  1  0  0
# 4176      0.3765        0.4950     12  13.5  0  0  1
#
# [4169 rows x 13 columns]

# %%
X=aba.drop(['rings', 'age', 'length'], axis=1)

# %%
X
# Out:
#      sex  diameter  height  whole_weight  shucked_weight_meat  gut_weight  \
# 0      M     0.365   0.095        0.5140               0.2245      0.1010
# 1      M     0.265   0.090        0.2255               0.0995      0.0485
# 2      F     0.420   0.135        0.6770               0.2565      0.1415
# 3      M     0.365   0.125        0.5160               0.2155      0.1140
# 4      I     0.255   0.080        0.2050               0.0895      0.0395
# ...   ..       ...     ...           ...                  ...         ...
# 4172   F     0.450   0.165        0.8870               0.3700      0.2390
# 4173   M     0.440   0.135        0.9660               0.4390      0.2145
# 4174   M     0.475   0.205        1.1760               0.5255      0.2875
# 4175   F     0.485   0.150        1.0945               0.5310      0.2610
# 4176   M     0.555   0.195        1.9485               0.9455      0.3765
#
#       shell_weight  F  I  M
# 0           0.1500  0  0  1
# 1           0.0700  0  0  1
# 2           0.2100  1  0  0
# 3           0.1550  0  0  1
# 4           0.0550  0  1  0
# ...            ... .. .. ..
# 4172        0.2490  1  0  0
# 4173        0.2605  0  0  1
# 4174        0.3080  0  0  1
# 4175        0.2960  1  0  0
# 4176        0.4950  0  0  1
#
# [4169 rows x 10 columns]

# %%
y=aba.rings

# %%
sex_num=sex_num.astype('Int64')

# %%
aba.dtypes
# Out:
# sex                     object
# length                 float64
# diameter               float64
# height                 float64
# whole_weight           float64
# shucked_weight_meat    float64
# gut_weight             float64
# shell_weight           float64
# rings                    int64
# age                    float64
# F                        uint8
# I                        uint8
# M                        uint8
# dtype: object

# %%
X=X._get_numeric_data()
X
# Out:
#       diameter  height  whole_weight  shucked_weight_meat  gut_weight  \
# 0        0.365   0.095        0.5140               0.2245      0.1010
# 1        0.265   0.090        0.2255               0.0995      0.0485
# 2        0.420   0.135        0.6770               0.2565      0.1415
# 3        0.365   0.125        0.5160               0.2155      0.1140
# 4        0.255   0.080        0.2050               0.0895      0.0395
# ...        ...     ...           ...                  ...         ...
# 4172     0.450   0.165        0.8870               0.3700      0.2390
# 4173     0.440   0.135        0.9660               0.4390      0.2145
# 4174     0.475   0.205        1.1760               0.5255      0.2875
# 4175     0.485   0.150        1.0945               0.5310      0.2610
# 4176     0.555   0.195        1.9485               0.9455      0.3765
#
#       shell_weight  F  I  M
# 0           0.1500  0  0  1
# 1           0.0700  0  0  1
# 2           0.2100  1  0  0
# 3           0.1550  0  0  1
# 4           0.0550  0  1  0
# ...            ... .. .. ..
# 4172        0.2490  1  0  0
# 4173        0.2605  0  0  1
# 4174        0.3080  0  0  1
# 4175        0.2960  1  0  0
# 4176        0.4950  0  0  1
#
# [4169 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=.30,random_state=123)

# %%
std_scaler=StandardScaler().fit(X_train)

# %%
X_train_scaled=std_scaler.transform(X_train)

# %%
X_train_scaled=std_scaler.transform(X_train)

# %%
X_train.shape
# Out:
# (2918, 9)

# %%
X_test_scaled=std_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 0.57456063,  0.27723626,  0.31208555, ..., -0.68342438,
#         -0.68990847,  1.33579607],
#        [-2.29541266, -2.19034006, -1.58553647, ..., -0.68342438,
#          1.44946764, -0.74861726],
#        [-1.84225899, -1.80072275, -1.39464534, ...,  1.46321968,
#         -0.68990847, -0.74861726],
#        ...,
#        [ 0.47385981,  0.4071087 ,  0.11811553, ..., -0.68342438,
#         -0.68990847,  1.33579607],
#        [ 0.62491103,  0.79672602,  0.87654856, ...,  1.46321968,
#         -0.68990847, -0.74861726],
#        [ 1.12841512,  1.44608821,  1.64113937, ...,  1.46321968,
#         -0.68990847, -0.74861726]])

# %%
X_test_scaled
# Out:
# array([[ 0.52421022,  0.53698114,  0.84473337, ..., -0.68342438,
#          1.44946764, -0.74861726],
#        [ 0.77596226,  0.92659845,  0.90220597, ..., -0.68342438,
#         -0.68990847,  1.33579607],
#        [-0.23104591,  0.14736383, -0.43197933, ..., -0.68342438,
#         -0.68990847,  1.33579607],
#        ...,
#        [-0.83525081, -0.50199837, -0.98925827, ..., -0.68342438,
#          1.44946764, -0.74861726],
#        [-1.18770367, -1.02148812, -1.11549273, ..., -0.68342438,
#          1.44946764, -0.74861726],
#        [-0.88560122, -1.54097787, -1.01696827, ..., -0.68342438,
#          1.44946764, -0.74861726]])

# %%
X.columns
# Out:
# Index(['diameter', 'height', 'whole_weight', 'shucked_weight_meat',
#        'gut_weight', 'shell_weight', 'F', 'I', 'M'],
#       dtype='object')

# %%
model=LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 0.84185376,  0.80592077,  4.12175045, -4.23602848, -1.07134934,
#         1.17521954,  0.1042907 , -0.22667022,  0.11957949])

# %%
model.intercept_
# Out:
# 9.898903358464702

# %%
y_pred=model.predict(X_test_scaled)

# %%
y_pred_train=model.predict(X_train_scaled)

# %%
y_pred=model.predict(X_test_scaled)
y_pred_train=model.predict(X_test_scaled)

# %%
y_test
# Out:
# 2394    14
# 2251    13
# 670     14
# 2744    11
# 4172    11
#         ..
# 1744    11
# 3486     8
# 2010     7
# 4164     7
# 112      9
# Name: rings, Length: 1251, dtype: int64

# %%
X
# Out:
#       diameter  height  whole_weight  shucked_weight_meat  gut_weight  \
# 0        0.365   0.095        0.5140               0.2245      0.1010
# 1        0.265   0.090        0.2255               0.0995      0.0485
# 2        0.420   0.135        0.6770               0.2565      0.1415
# 3        0.365   0.125        0.5160               0.2155      0.1140
# 4        0.255   0.080        0.2050               0.0895      0.0395
# ...        ...     ...           ...                  ...         ...
# 4172     0.450   0.165        0.8870               0.3700      0.2390
# 4173     0.440   0.135        0.9660               0.4390      0.2145
# 4174     0.475   0.205        1.1760               0.5255      0.2875
# 4175     0.485   0.150        1.0945               0.5310      0.2610
# 4176     0.555   0.195        1.9485               0.9455      0.3765
#
#       shell_weight  F  I  M
# 0           0.1500  0  0  1
# 1           0.0700  0  0  1
# 2           0.2100  1  0  0
# 3           0.1550  0  0  1
# 4           0.0550  0  1  0
# ...            ... .. .. ..
# 4172        0.2490  1  0  0
# 4173        0.2605  0  0  1
# 4174        0.3080  0  0  1
# 4175        0.2960  1  0  0
# 4176        0.4950  0  0  1
#
# [4169 rows x 9 columns]

# %%
model.score(X_test, y_test)
# Out:
# -0.2383606266183964

# %%
result=pd.DataFrame({'y_test':y_test, 'y_pred':y_pred})
print(result)
# Out:
#       y_test     y_pred
# 2394      14  10.392307
# 2251      13  12.774801
# 670       14  11.180491
# 2744      11   9.418616
# 4172      11  10.814718
# ...      ...        ...
# 1744      11  10.800514
# 3486       8  10.676138
# 2010       7   7.792672
# 4164       7   7.282543
# 112        9   7.286757
#
# [1251 rows x 2 columns]

# %%
fig, ax= plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred, y_test, 'o')
ax[0].set_xlabel('y_test')
ax[0].set_ylabel('y_pred')
ax[0].set_title('Test Set - Predicted vs real')

ax[1].hist(y_test - y_pred)
ax[1].set_xlabel('Test y-y_pred')
ax[1].set_title('Test Set Residual histogram')

ax[2].plot(y_pred,y_test - y_pred, 'o')
ax[2].set_xlabel('predicted')
ax[2].set_ylabel('residuals')
ax[2].set_title('Residuals by Predicted')
ax[2].plot(y_pred,np.zeros(len(y_pred)), linestyle='dashed')

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %%
from sklearn.metrics import r2_score

# %%
print(mse(y_test, y_pred))
print(mae(y_test, y_pred))
# Out:
# 4.93273909971621
# 1.6032076101009873

# %%
R2=r2_score(y_test,y_pred)

# %%
R2
# Out:
# 0.49750576007889624

# %%
model.score(X_test, y_test)
# Out:
# -0.2383606266183964

# %%
R2_test=model.score(X_test_scaled,y_test)
R2_train=model.score(X_train_scaled,y_train)

# %%
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
Adj_R2
# Out:
# 0.4938615633349076

# %%
features_importances = pd.DataFrame(data={'Attribute': X_train.columns,'Importance': abs(model.coef_)})
features_importances = features_importances.sort_values(by='Importance', ascending=False)

# %%
features_importances
# Out:
#              Attribute  Importance
# 3  shucked_weight_meat    4.236028
# 2         whole_weight    4.121750
# 5         shell_weight    1.175220
# 4           gut_weight    1.071349
# 0             diameter    0.841854
# 1               height    0.805921
# 7                    I    0.226670
# 8                    M    0.119579
# 6                    F    0.104291

# %%
plt.bar(x=features_importances['Attribute'], height=features_importances['Importance'], color='#087E8B')
plt.title('Feature importances obtained from coefficients', size=20)
plt.xticks(rotation='vertical')
plt.show()

# %%
X_train_const_scaled = sm.add_constant(X_train_scaled) # adding a constant

model = sm.OLS(y_train, X_train_const_scaled).fit()
predictions_train = model.predict(X_train_const_scaled) 

X_test_const_scaled = sm.add_constant(X_test_scaled) # adding a constant
predictions_test = model.predict(X_test_const_scaled) 
print_model = model.summary(xname=['const'] + list(X.columns))
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  rings   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     460.5
# Date:                Wed, 20 Apr 2022   Prob (F-statistic):               0.00
# Time:                        15:02:37   Log-Likelihood:                -6351.7
# No. Observations:                2918   AIC:                         1.272e+04
# Df Residuals:                    2909   BIC:                         1.278e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   9.8989      0.040    250.241      0.000       9.821       9.976
# diameter                0.8419      0.120      7.001      0.000       0.606       1.078
# height                  0.8059      0.101      7.983      0.000       0.608       1.004
# whole_weight            4.1218      0.424      9.720      0.000       3.290       4.953
# shucked_weight_meat    -4.2360      0.213    -19.878      0.000      -4.654      -3.818
# gut_weight             -1.0713      0.164     -6.530      0.000      -1.393      -0.750
# shell_weight            1.1752      0.191      6.168      0.000       0.802       1.549
# F                       0.1043      0.029      3.582      0.000       0.047       0.161
# I                      -0.2267      0.033     -6.932      0.000      -0.291      -0.163
# M                       0.1196      0.027      4.436      0.000       0.067       0.172
# ==============================================================================
# Omnibus:                      616.368   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1544.289
# Skew:                           1.146   Prob(JB):                         0.00
# Kurtosis:                       5.730   Cond. No.                     6.09e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.81e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
X
# Out:
#       diameter  height  whole_weight  shucked_weight_meat  gut_weight  \
# 0        0.365   0.095        0.5140               0.2245      0.1010
# 1        0.265   0.090        0.2255               0.0995      0.0485
# 2        0.420   0.135        0.6770               0.2565      0.1415
# 3        0.365   0.125        0.5160               0.2155      0.1140
# 4        0.255   0.080        0.2050               0.0895      0.0395
# ...        ...     ...           ...                  ...         ...
# 4172     0.450   0.165        0.8870               0.3700      0.2390
# 4173     0.440   0.135        0.9660               0.4390      0.2145
# 4174     0.475   0.205        1.1760               0.5255      0.2875
# 4175     0.485   0.150        1.0945               0.5310      0.2610
# 4176     0.555   0.195        1.9485               0.9455      0.3765
#
#       shell_weight  F  I  M
# 0           0.1500  0  0  1
# 1           0.0700  0  0  1
# 2           0.2100  1  0  0
# 3           0.1550  0  0  1
# 4           0.0550  0  1  0
# ...            ... .. .. ..
# 4172        0.2490  1  0  0
# 4173        0.2605  0  0  1
# 4174        0.3080  0  0  1
# 4175        0.2960  1  0  0
# 4176        0.4950  0  0  1
#
# [4169 rows x 9 columns]

# %% [markdown]
# Multikorrelation

# %%
corr = aba.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
from sklearn.linear_model import Lasso

reg = Lasso(alpha=1)
reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=1)

# %%
print('R squared training set', round(reg.score(X_train, y_train)*100, 2))
print('R squared test set', round(reg.score(X_test, y_test)*100, 2))
# Out:
# R squared training set 99.06
# R squared test set 99.06

# %%
import numpy as np
import matplotlib.pyplot as plt

alphas = np.linspace(0.01,500,100)
lasso = Lasso(max_iter=10000)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    coefs.append(lasso.coef_)

ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('Standardized Coefficients')
plt.title('Lasso coefficients as a function of alpha');

# %%
aba
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight_meat  \
# 0      M   0.455     0.365   0.095        0.5140               0.2245
# 1      M   0.350     0.265   0.090        0.2255               0.0995
# 2      F   0.530     0.420   0.135        0.6770               0.2565
# 3      M   0.440     0.365   0.125        0.5160               0.2155
# 4      I   0.330     0.255   0.080        0.2050               0.0895
# ...   ..     ...       ...     ...           ...                  ...
# 4172   F   0.565     0.450   0.165        0.8870               0.3700
# 4173   M   0.590     0.440   0.135        0.9660               0.4390
# 4174   M   0.600     0.475   0.205        1.1760               0.5255
# 4175   F   0.625     0.485   0.150        1.0945               0.5310
# 4176   M   0.710     0.555   0.195        1.9485               0.9455
#
#       gut_weight  shell_weight  rings   age  F  I  M
# 0         0.1010        0.1500     15  16.5  0  0  1
# 1         0.0485        0.0700      7   8.5  0  0  1
# 2         0.1415        0.2100      9  10.5  1  0  0
# 3         0.1140        0.1550     10  11.5  0  0  1
# 4         0.0395        0.0550      7   8.5  0  1  0
# ...          ...           ...    ...   ... .. .. ..
# 4172      0.2390        0.2490     11  12.5  1  0  0
# 4173      0.2145        0.2605     10  11.5  0  0  1
# 4174      0.2875        0.3080      9  10.5  0  0  1
# 4175      0.2610        0.2960     10  11.5  1  0  0
# 4176      0.3765        0.4950     12  13.5  0  0  1
#
# [4169 rows x 13 columns]

# %%
aba['age'].mean()
# Out:
# 11.418685536099785

# %%
aba.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train, y_train)
y_predicted5 = ridge.predict(X_test)
print(y_predicted5)
# Out:
# [10.51473865 12.63946454 10.85242844 ...  7.63943958  7.25983879
#   7.50352878]
